# %%
import pandas as pd

# Load the Benin dataset
df = pd.read_csv("C:/Users/nati/Downloads/solar-challenge-week1/data/data/sierraleone-bumbuna.csv")

# Preview the first few rows
df.head()
# Out:
#           Timestamp  GHI  DNI  DHI  ModA  ModB  Tamb    RH   WS  WSgust  \
# 0  2021-10-30 00:01 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.1  0.0     0.0
# 1  2021-10-30 00:02 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.2  0.0     0.0
# 2  2021-10-30 00:03 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.2  0.0     0.0
# 3  2021-10-30 00:04 -0.7  0.0 -0.8   0.0   0.0  21.9  99.3  0.0     0.0
# 4  2021-10-30 00:05 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.3  0.0     0.0
#
#    WSstdev   WD  WDstdev    BP  Cleaning  Precipitation  TModA  TModB  \
# 0      0.0  0.0      0.0  1002         0            0.0   22.3   22.6
# 1      0.0  0.0      0.0  1002         0            0.0   22.3   22.6
# 2      0.0  0.0      0.0  1002         0            0.0   22.3   22.6
# 3      0.0  0.0      0.0  1002         0            0.1   22.3   22.6
# 4      0.0  0.0      0.0  1002         0            0.0   22.3   22.6
#
#    Comments
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
# Summary statistics
df.describe()

# Missing values
missing_report = df.isna().sum()
missing_percent = (missing_report / len(df)) * 100
missing_report[missing_percent > 5]
# Out:
# Comments    525600
# dtype: int64

# %%
from scipy.stats import zscore

columns_to_check = ['GHI', 'DNI', 'DHI', 'ModA', 'ModB', 'WS', 'WSgust']
z_scores = df[columns_to_check].apply(zscore)

# Flagging outliers
outliers = (z_scores.abs() > 3)
outlier_rows = outliers.any(axis=1)
print("Outlier rows:", outlier_rows.sum())
# Out:
# Outlier rows: 16292

# %%
# Drop rows or impute with median
df_clean = df.copy()
df_clean[columns_to_check] = df_clean[columns_to_check].fillna(df_clean[columns_to_check].median())

# %%
import os

# Create outputs/ folder if it doesn't exist
os.makedirs('../outputs', exist_ok=True)

# Now save the cleaned CSV
df_clean.to_csv('../outputs/sierraleone-bumbuna.csv', index=False)

# %%
df_clean.to_csv('../outputs/sierraleone-bumbuna.csv', index=False)

# %%
import matplotlib.pyplot as plt

df_clean['Timestamp'] = pd.to_datetime(df_clean['Timestamp'])
df_clean.set_index('Timestamp', inplace=True)

df_clean[['GHI', 'DNI', 'DHI', 'Tamb']].plot(figsize=(15,6))
plt.title('Solar Irradiance & Temperature over Time')
plt.show()

# %%
df_clean.groupby('Cleaning')[['ModA', 'ModB']].mean().plot(kind='bar', title='Effect of Cleaning on ModA & ModB')
# Out:
# <Axes: title={'center': 'Effect of Cleaning on ModA & ModB'}, xlabel='Cleaning'>

# %%
import seaborn as sns

corr = df_clean[['GHI', 'DNI', 'DHI', 'TModA', 'TModB']].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.scatterplot(data=df_clean, x='WS', y='GHI')
sns.scatterplot(data=df_clean, x='RH', y='Tamb')
# Out:
# <Axes: xlabel='WS', ylabel='GHI'>

# %%
df_clean['WS'].hist(bins=30)
# Out:
# <Axes: >

# %%
pip install windrose
# Out:
# Requirement already satisfied: windrose in c:\users\nati\downloads\solar-challenge-week1\.venv\lib\site-packages (1.9.2)
# Requirement already satisfied: matplotlib>=3 in c:\users\nati\downloads\solar-challenge-week1\.venv\lib\site-packages (from windrose) (3.10.3)
# Requirement already satisfied: numpy>=1.21 in c:\users\nati\downloads\solar-challenge-week1\.venv\lib\site-packages (from windrose) (2.2.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\nati\downloads\solar-challenge-week1\.venv\lib\site-packages (from matplotlib>=3->windrose) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\nati\downloads\solar-challenge-week1\.venv\lib\site-packages (from matplotlib>=3->windrose) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\nati\downloads\solar-challenge-week1\.venv\lib\site-packages (from matplotlib>=3->windrose) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\nati\downloads\solar-challenge-week1\.venv\lib\site-packages (from matplotlib>=3->windrose) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\nati\downloads\solar-challenge-week1\.venv\lib\site-packages (from matplotlib>=3->windrose) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\nati\downloads\solar-challenge-week1\.venv\lib\site-packages (from matplotlib>=3->windrose) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\nati\downloads\solar-challenge-week1\.venv\lib\site-packages (from matplotlib>=3->windrose) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\nati\downloads\solar-challenge-week1\.venv\lib\site-packages (from matplotlib>=3->windrose) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\nati\downloads\solar-challenge-week1\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3->windrose) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from windrose import WindroseAxes

ax = WindroseAxes.from_ax()
ax.bar(df_clean['WD'], df_clean['WS'], normed=True, opening=0.8, edgecolor='white')

# %%
sns.scatterplot(data=df_clean, x='RH', y='Tamb')
sns.scatterplot(data=df_clean, x='RH', y='GHI')
# Out:
# <Axes: xlabel='RH', ylabel='Tamb'>

# %%
plt.figure(figsize=(10,6))
plt.scatter(df_clean['GHI'], df_clean['Tamb'], s=df_clean['RH'], alpha=0.5)
plt.xlabel('GHI')
plt.ylabel('Tamb')
plt.title('GHI vs Tamb (Bubble size = RH)')
plt.show()
